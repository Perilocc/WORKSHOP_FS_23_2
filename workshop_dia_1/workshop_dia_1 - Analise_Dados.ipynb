# %% [markdown]
# # Perguntas acerca do Mercado Financeiro Brasileiro e suas ações
# - 1 - Você sabe o que é Mercado Financeiro?
# - 2 - Você conhece alguma ação ou fundo de investimentos?
# - 3 - Você acha importante aprender sobre investimentos e as mudanças do Mercado?
# - 4 - Entre 1 e 5, qual seu nível de conhecimento sobre este assunto?
# - 5 - Você acha que as escolas deveriam ensinar os jovens matérias com este tema?
# - 6 - Você investe?
# - 7 - Caso você tivesse capital para investir, você investiria hoje?
# - 8 - Você tem medo do Mercado Financeiro e Bolsa de valores ou você não tem conhecimento para julga-los como bom ou ruim?
# - 9 - Você sabe como funcionam as ações e seus pagamentos em dividendos?
# - 10 - Você investe em cdb?

# %%
# !pip install yfinance

# %%
import yfinance as yf
acao = input('Digite o código da ação: ')
dados = yf.Ticker(acao).history("1y")
fechamento = dados.Close
fechamento
# Out:
# Digite o código da ação: BBAS3.SA
# Date
# 2022-08-29 00:00:00-03:00    38.928406
# 2022-08-30 00:00:00-03:00    38.818363
# 2022-08-31 00:00:00-03:00    38.231453
# 2022-09-01 00:00:00-03:00    38.818363
# 2022-09-02 00:00:00-03:00    39.001770
#                                ...
# 2023-08-22 00:00:00-03:00    47.970001
# 2023-08-23 00:00:00-03:00    48.180000
# 2023-08-24 00:00:00-03:00    47.549999
# 2023-08-25 00:00:00-03:00    46.930000
# 2023-08-28 00:00:00-03:00    48.279999
# Name: Close, Length: 250, dtype: float64

# %% [markdown]
# # Análise de Dados sobre uma ação!

# %%
fechamento.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
